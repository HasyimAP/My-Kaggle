# %%
import os
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt

from datetime import datetime
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.applications.vgg19 import VGG19

# %% [markdown]
# # Set Hyperparameter

# %%
height = 256
width = 256
channels = 3
batch_size = 32
img_shape = (height, width, channels)
img_size = (height, width)

# %% [markdown]
# # Split The Dataset

# %%
DATA_DIR = '../input/workoutexercises-images'

train_ds = tf.keras.utils.image_dataset_from_directory(DATA_DIR,
                                                       labels = 'inferred',
                                                       label_mode = 'categorical',
                                                       validation_split = 0.1,
                                                       subset = 'training',
                                                       image_size = img_size,
                                                       shuffle = True,
                                                       batch_size = batch_size,
                                                       seed = 127
                                                      )

val_ds = tf.keras.utils.image_dataset_from_directory(DATA_DIR,
                                                     labels = 'inferred',
                                                     label_mode = 'categorical',
                                                     validation_split = 0.1,
                                                     subset = 'validation',
                                                     image_size = img_size,
                                                     shuffle = True,
                                                     batch_size = batch_size,
                                                     seed = 127
                                                    )

labels = train_ds.class_names
print(labels)

with open('workout_label.txt', 'w') as f:
    for workout_class in labels:
        f.write(f'{workout_class}\n')
# Out:
# Found 13853 files belonging to 22 classes.
# Using 12468 files for training.
# Found 13853 files belonging to 22 classes.
# Using 1385 files for validation.
# ['barbell biceps curl', 'bench press', 'chest fly machine', 'deadlift', 'decline bench press', 'hammer curl', 'hip thrust', 'incline bench press', 'lat pulldown', 'lateral raises', 'leg extension', 'leg raises', 'plank', 'pull up', 'push up', 'romanian deadlift', 'russian twist', 'shoulder press', 'squat', 't bar row', 'tricep dips', 'tricep pushdown']

# %% [markdown]
# # Data Augmentation

# %%
data_augmentation = tf.keras.Sequential([tf.keras.layers.RandomFlip("horizontal"),
                                         tf.keras.layers.GaussianNoise(10),
                                         tf.keras.layers.RandomContrast(0.1),
                                         tf.keras.layers.RandomZoom(0.2)
                                        ])

train_ds = train_ds.map(lambda x, y: (data_augmentation(x), y))

# %%
#Defing a function to see images
def show_img(data):
    plt.figure(figsize=(10,10))
    for images, labels in data.take(1):
        for i in range(9):
            ax = plt.subplot(3, 3, i + 1)
            ax.imshow(images[i].numpy().astype("uint8"))
            ax.axis("off")

#Plotting the images in dataset
show_img(train_ds)

# %% [markdown]
# # Load Pre-Trained Model

# %%
# load pre-trained VGG19
pre_trained = VGG19(weights='imagenet', include_top=False, input_shape=img_shape, pooling='avg')

for layer in pre_trained.layers:
    layer.trainable = False
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80134624/80134624 [==============================] - 0s 0us/step

# %%
x = pre_trained.output

predictions = tf.keras.layers.Dense(len(labels), activation='softmax')(x)

workout_model = tf.keras.models.Model(inputs = pre_trained.input, 
                                      outputs = predictions
                                     )

workout_model.compile(optimizer = tf.keras.optimizers.Adam(learning_rate=0.0001),
                      loss='categorical_crossentropy',
                      metrics=['accuracy']
                     )

workout_model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 256, 256, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 256, 256, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 256, 256, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 128, 128, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 128, 128, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 128, 128, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 64, 64, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 64, 64, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 64, 64, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 64, 64, 256)       590080
#
#  block3_conv4 (Conv2D)       (None, 64, 64, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 32, 32, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 32, 32, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 32, 32, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 32, 32, 512)       2359808
#
#  block4_conv4 (Conv2D)       (None, 32, 32, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 16, 16, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 16, 16, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 16, 16, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 16, 16, 512)       2359808
#
#  block5_conv4 (Conv2D)       (None, 16, 16, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 8, 8, 512)         0
#
#  global_average_pooling2d (G  (None, 512)              0
#  lobalAveragePooling2D)
#
#  dense (Dense)               (None, 22)                11286
#
# =================================================================
# Total params: 20,035,670
# Trainable params: 11,286
# Non-trainable params: 20,024,384
# _________________________________________________________________

# %% [markdown]
# # Train Model With Dataset

# %%
early_stopping_callback = EarlyStopping(monitor = 'val_loss', 
                                        patience = 5, 
                                        mode = 'auto', 
                                        restore_best_weights = True
                                       )

history = workout_model.fit(train_ds,
                            validation_data = val_ds,
                            epochs = 100
#                             callbacks = [early_stopping_callback]
                           )
# Out:
# Epoch 1/100
# 390/390 [==============================] - 150s 358ms/step - loss: 5.3627 - accuracy: 0.1541 - val_loss: 3.7066 - val_accuracy: 0.2693
# Epoch 2/100
# 390/390 [==============================] - 113s 289ms/step - loss: 2.9151 - accuracy: 0.3423 - val_loss: 2.2648 - val_accuracy: 0.4578
# Epoch 3/100
# 390/390 [==============================] - 119s 304ms/step - loss: 1.9477 - accuracy: 0.4958 - val_loss: 1.5683 - val_accuracy: 0.5863
# Epoch 4/100
# 390/390 [==============================] - 121s 308ms/step - loss: 1.3982 - accuracy: 0.6185 - val_loss: 1.1844 - val_accuracy: 0.6679
# Epoch 5/100
# 390/390 [==============================] - 121s 309ms/step - loss: 1.0937 - accuracy: 0.6900 - val_loss: 0.9309 - val_accuracy: 0.7264
# Epoch 6/100
# 390/390 [==============================] - 120s 305ms/step - loss: 0.8922 - accuracy: 0.7479 - val_loss: 0.7669 - val_accuracy: 0.7762
# Epoch 7/100
# 390/390 [==============================] - 121s 308ms/step - loss: 0.7449 - accuracy: 0.7870 - val_loss: 0.6521 - val_accuracy: 0.8159
# Epoch 8/100
# 390/390 [==============================] - 120s 307ms/step - loss: 0.6285 - accuracy: 0.8211 - val_loss: 0.5520 - val_accuracy: 0.8383
# Epoch 9/100
# 390/390 [==============================] - 113s 289ms/step - loss: 0.5414 - accuracy: 0.8500 - val_loss: 0.4755 - val_accuracy: 0.8621
# Epoch 10/100
# 390/390 [==============================] - 111s 284ms/step - loss: 0.4782 - accuracy: 0.8660 - val_loss: 0.4243 - val_accuracy: 0.8823
# Epoch 11/100
# 390/390 [==============================] - 111s 283ms/step - loss: 0.4255 - accuracy: 0.8823 - val_loss: 0.3782 - val_accuracy: 0.8953
# Epoch 12/100
# 390/390 [==============================] - 112s 285ms/step - loss: 0.3765 - accuracy: 0.9005 - val_loss: 0.3401 - val_accuracy: 0.9141
# Epoch 13/100
# 390/390 [==============================] - 111s 282ms/step - loss: 0.3365 - accuracy: 0.9138 - val_loss: 0.3124 - val_accuracy: 0.9213
# Epoch 14/100
# 390/390 [==============================] - 112s 284ms/step - loss: 0.3066 - accuracy: 0.9216 - val_loss: 0.2884 - val_accuracy: 0.9271
# Epoch 15/100
# 390/390 [==============================] - 111s 283ms/step - loss: 0.2880 - accuracy: 0.9296 - val_loss: 0.2627 - val_accuracy: 0.9329
# Epoch 16/100
# 390/390 [==============================] - 113s 289ms/step - loss: 0.2568 - accuracy: 0.9354 - val_loss: 0.2455 - val_accuracy: 0.9379
# Epoch 17/100
# 390/390 [==============================] - 112s 285ms/step - loss: 0.2376 - accuracy: 0.9420 - val_loss: 0.2323 - val_accuracy: 0.9408
# Epoch 18/100
# 390/390 [==============================] - 113s 287ms/step - loss: 0.2180 - accuracy: 0.9475 - val_loss: 0.2209 - val_accuracy: 0.9451
# Epoch 19/100
# 390/390 [==============================] - 112s 286ms/step - loss: 0.2036 - accuracy: 0.9512 - val_loss: 0.2069 - val_accuracy: 0.9523
# Epoch 20/100
# 390/390 [==============================] - 112s 286ms/step - loss: 0.1981 - accuracy: 0.9523 - val_loss: 0.1979 - val_accuracy: 0.9545
# Epoch 21/100
# 390/390 [==============================] - 112s 286ms/step - loss: 0.1801 - accuracy: 0.9585 - val_loss: 0.1900 - val_accuracy: 0.9574
# Epoch 22/100
# 390/390 [==============================] - 113s 287ms/step - loss: 0.1678 - accuracy: 0.9623 - val_loss: 0.1714 - val_accuracy: 0.9617
# Epoch 23/100
# 390/390 [==============================] - 113s 287ms/step - loss: 0.1577 - accuracy: 0.9633 - val_loss: 0.1724 - val_accuracy: 0.9603
# Epoch 24/100
# 390/390 [==============================] - 114s 289ms/step - loss: 0.1426 - accuracy: 0.9683 - val_loss: 0.1585 - val_accuracy: 0.9646
# Epoch 25/100
# 390/390 [==============================] - 114s 292ms/step - loss: 0.1356 - accuracy: 0.9699 - val_loss: 0.1562 - val_accuracy: 0.9653
# Epoch 26/100
# 390/390 [==============================] - 115s 293ms/step - loss: 0.1327 - accuracy: 0.9700 - val_loss: 0.1496 - val_accuracy: 0.9668
# Epoch 27/100
# 390/390 [==============================] - 122s 310ms/step - loss: 0.1239 - accuracy: 0.9725 - val_loss: 0.1483 - val_accuracy: 0.9653
# Epoch 28/100
# 390/390 [==============================] - 122s 312ms/step - loss: 0.1215 - accuracy: 0.9729 - val_loss: 0.1436 - val_accuracy: 0.9668
# Epoch 29/100
# 390/390 [==============================] - 126s 320ms/step - loss: 0.1127 - accuracy: 0.9756 - val_loss: 0.1383 - val_accuracy: 0.9704
# Epoch 30/100
# 390/390 [==============================] - 123s 314ms/step - loss: 0.1051 - accuracy: 0.9769 - val_loss: 0.1350 - val_accuracy: 0.9697
# Epoch 31/100
# 390/390 [==============================] - 124s 315ms/step - loss: 0.0977 - accuracy: 0.9791 - val_loss: 0.1303 - val_accuracy: 0.9697
# Epoch 32/100
# 390/390 [==============================] - 123s 312ms/step - loss: 0.0945 - accuracy: 0.9807 - val_loss: 0.1274 - val_accuracy: 0.9704
# Epoch 33/100
# 390/390 [==============================] - 122s 312ms/step - loss: 0.0886 - accuracy: 0.9809 - val_loss: 0.1266 - val_accuracy: 0.9733
# Epoch 34/100
# 390/390 [==============================] - 122s 312ms/step - loss: 0.0843 - accuracy: 0.9822 - val_loss: 0.1212 - val_accuracy: 0.9755
# Epoch 35/100
# 390/390 [==============================] - 122s 309ms/step - loss: 0.0806 - accuracy: 0.9833 - val_loss: 0.1204 - val_accuracy: 0.9755
# Epoch 36/100
# 390/390 [==============================] - 123s 313ms/step - loss: 0.0806 - accuracy: 0.9841 - val_loss: 0.1165 - val_accuracy: 0.9776
# Epoch 37/100
# 390/390 [==============================] - 122s 312ms/step - loss: 0.0799 - accuracy: 0.9838 - val_loss: 0.1167 - val_accuracy: 0.9755
# Epoch 38/100
# 390/390 [==============================] - 123s 313ms/step - loss: 0.0714 - accuracy: 0.9840 - val_loss: 0.1114 - val_accuracy: 0.9769
# Epoch 39/100
# 390/390 [==============================] - 123s 313ms/step - loss: 0.0677 - accuracy: 0.9856 - val_loss: 0.1098 - val_accuracy: 0.9762
# Epoch 40/100
# 390/390 [==============================] - 122s 311ms/step - loss: 0.0639 - accuracy: 0.9880 - val_loss: 0.1096 - val_accuracy: 0.9791
# Epoch 41/100
# 390/390 [==============================] - 124s 318ms/step - loss: 0.0625 - accuracy: 0.9881 - val_loss: 0.1038 - val_accuracy: 0.9776
# Epoch 42/100
# 390/390 [==============================] - 122s 310ms/step - loss: 0.0588 - accuracy: 0.9895 - val_loss: 0.1070 - val_accuracy: 0.9783
# Epoch 43/100
# 390/390 [==============================] - 123s 313ms/step - loss: 0.0554 - accuracy: 0.9901 - val_loss: 0.1034 - val_accuracy: 0.9783
# Epoch 44/100
# 390/390 [==============================] - 124s 318ms/step - loss: 0.0512 - accuracy: 0.9911 - val_loss: 0.1002 - val_accuracy: 0.9791
# Epoch 45/100
# 390/390 [==============================] - 122s 312ms/step - loss: 0.0551 - accuracy: 0.9894 - val_loss: 0.1004 - val_accuracy: 0.9791
# Epoch 46/100
# 390/390 [==============================] - 123s 313ms/step - loss: 0.0520 - accuracy: 0.9913 - val_loss: 0.0991 - val_accuracy: 0.9805
# Epoch 47/100
# 390/390 [==============================] - 124s 318ms/step - loss: 0.0486 - accuracy: 0.9913 - val_loss: 0.0993 - val_accuracy: 0.9805
# Epoch 48/100
# 390/390 [==============================] - 126s 319ms/step - loss: 0.0485 - accuracy: 0.9905 - val_loss: 0.0970 - val_accuracy: 0.9805
# Epoch 49/100
# 390/390 [==============================] - 124s 316ms/step - loss: 0.0451 - accuracy: 0.9920 - val_loss: 0.0966 - val_accuracy: 0.9805
# Epoch 50/100
# 390/390 [==============================] - 124s 314ms/step - loss: 0.0456 - accuracy: 0.9919 - val_loss: 0.0988 - val_accuracy: 0.9812
# Epoch 51/100
# 390/390 [==============================] - 125s 319ms/step - loss: 0.0424 - accuracy: 0.9925 - val_loss: 0.0973 - val_accuracy: 0.9798
# Epoch 52/100
# 390/390 [==============================] - 123s 314ms/step - loss: 0.0413 - accuracy: 0.9931 - val_loss: 0.0947 - val_accuracy: 0.9805
# Epoch 53/100
# 390/390 [==============================] - 123s 312ms/step - loss: 0.0419 - accuracy: 0.9935 - val_loss: 0.0993 - val_accuracy: 0.9805
# Epoch 54/100
# 390/390 [==============================] - 126s 322ms/step - loss: 0.0376 - accuracy: 0.9936 - val_loss: 0.0998 - val_accuracy: 0.9805
# Epoch 55/100
# 390/390 [==============================] - 124s 318ms/step - loss: 0.0382 - accuracy: 0.9939 - val_loss: 0.0945 - val_accuracy: 0.9805
# Epoch 56/100
# 390/390 [==============================] - 124s 316ms/step - loss: 0.0369 - accuracy: 0.9941 - val_loss: 0.0927 - val_accuracy: 0.9819
# Epoch 57/100
# 390/390 [==============================] - 124s 315ms/step - loss: 0.0347 - accuracy: 0.9941 - val_loss: 0.0954 - val_accuracy: 0.9827
# Epoch 58/100
# 390/390 [==============================] - 124s 315ms/step - loss: 0.0334 - accuracy: 0.9945 - val_loss: 0.0908 - val_accuracy: 0.9819
# Epoch 59/100
# 390/390 [==============================] - 125s 319ms/step - loss: 0.0336 - accuracy: 0.9937 - val_loss: 0.0892 - val_accuracy: 0.9791
# Epoch 60/100
# 390/390 [==============================] - 125s 318ms/step - loss: 0.0339 - accuracy: 0.9943 - val_loss: 0.0924 - val_accuracy: 0.9805
# Epoch 61/100
# 390/390 [==============================] - 126s 319ms/step - loss: 0.0296 - accuracy: 0.9956 - val_loss: 0.0909 - val_accuracy: 0.9819
# Epoch 62/100
# 390/390 [==============================] - 125s 317ms/step - loss: 0.0314 - accuracy: 0.9951 - val_loss: 0.0899 - val_accuracy: 0.9805
# Epoch 63/100
# 390/390 [==============================] - 126s 320ms/step - loss: 0.0296 - accuracy: 0.9953 - val_loss: 0.0892 - val_accuracy: 0.9812
# Epoch 64/100
# 390/390 [==============================] - 125s 317ms/step - loss: 0.0281 - accuracy: 0.9962 - val_loss: 0.0918 - val_accuracy: 0.9827
# Epoch 65/100
# 390/390 [==============================] - 124s 317ms/step - loss: 0.0275 - accuracy: 0.9953 - val_loss: 0.0901 - val_accuracy: 0.9827
# Epoch 66/100
# 390/390 [==============================] - 125s 319ms/step - loss: 0.0255 - accuracy: 0.9969 - val_loss: 0.0875 - val_accuracy: 0.9848
# Epoch 67/100
# 390/390 [==============================] - 125s 318ms/step - loss: 0.0248 - accuracy: 0.9972 - val_loss: 0.0873 - val_accuracy: 0.9827
# Epoch 68/100
# 390/390 [==============================] - 126s 319ms/step - loss: 0.0256 - accuracy: 0.9964 - val_loss: 0.0857 - val_accuracy: 0.9841
# Epoch 69/100
# 390/390 [==============================] - 126s 321ms/step - loss: 0.0256 - accuracy: 0.9965 - val_loss: 0.0873 - val_accuracy: 0.9848
# Epoch 70/100
# 390/390 [==============================] - 125s 318ms/step - loss: 0.0239 - accuracy: 0.9966 - val_loss: 0.0914 - val_accuracy: 0.9827
# Epoch 71/100
# 390/390 [==============================] - 125s 317ms/step - loss: 0.0231 - accuracy: 0.9969 - val_loss: 0.0886 - val_accuracy: 0.9834
# Epoch 72/100
# 390/390 [==============================] - 124s 316ms/step - loss: 0.0218 - accuracy: 0.9972 - val_loss: 0.0853 - val_accuracy: 0.9841
# Epoch 73/100
# 390/390 [==============================] - 125s 317ms/step - loss: 0.0237 - accuracy: 0.9966 - val_loss: 0.0877 - val_accuracy: 0.9827
# Epoch 74/100
# 390/390 [==============================] - 124s 318ms/step - loss: 0.0218 - accuracy: 0.9971 - val_loss: 0.0829 - val_accuracy: 0.9856
# Epoch 75/100
# 390/390 [==============================] - 125s 318ms/step - loss: 0.0222 - accuracy: 0.9962 - val_loss: 0.0852 - val_accuracy: 0.9856
# Epoch 76/100
# 390/390 [==============================] - 124s 316ms/step - loss: 0.0191 - accuracy: 0.9981 - val_loss: 0.0817 - val_accuracy: 0.9856
# Epoch 77/100
# 390/390 [==============================] - 126s 320ms/step - loss: 0.0208 - accuracy: 0.9975 - val_loss: 0.0841 - val_accuracy: 0.9848
# Epoch 78/100
# 390/390 [==============================] - 126s 320ms/step - loss: 0.0188 - accuracy: 0.9978 - val_loss: 0.0832 - val_accuracy: 0.9856
# Epoch 79/100
# 390/390 [==============================] - 128s 325ms/step - loss: 0.0185 - accuracy: 0.9975 - val_loss: 0.0851 - val_accuracy: 0.9848
# Epoch 80/100
# 390/390 [==============================] - 126s 321ms/step - loss: 0.0186 - accuracy: 0.9977 - val_loss: 0.0857 - val_accuracy: 0.9863
# Epoch 81/100
# 390/390 [==============================] - 129s 330ms/step - loss: 0.0186 - accuracy: 0.9977 - val_loss: 0.0856 - val_accuracy: 0.9841
# Epoch 82/100
# 390/390 [==============================] - 125s 320ms/step - loss: 0.0174 - accuracy: 0.9982 - val_loss: 0.0827 - val_accuracy: 0.9863
# Epoch 83/100
# 390/390 [==============================] - 126s 320ms/step - loss: 0.0175 - accuracy: 0.9984 - val_loss: 0.0811 - val_accuracy: 0.9863
# Epoch 84/100
# 390/390 [==============================] - 125s 318ms/step - loss: 0.0177 - accuracy: 0.9979 - val_loss: 0.0864 - val_accuracy: 0.9848
# Epoch 85/100
# 390/390 [==============================] - 126s 320ms/step - loss: 0.0175 - accuracy: 0.9976 - val_loss: 0.0865 - val_accuracy: 0.9856
# Epoch 86/100
# 390/390 [==============================] - 127s 323ms/step - loss: 0.0164 - accuracy: 0.9985 - val_loss: 0.0798 - val_accuracy: 0.9863
# Epoch 87/100
# 390/390 [==============================] - 124s 317ms/step - loss: 0.0161 - accuracy: 0.9983 - val_loss: 0.0823 - val_accuracy: 0.9841
# Epoch 88/100
# 390/390 [==============================] - 127s 324ms/step - loss: 0.0156 - accuracy: 0.9982 - val_loss: 0.0865 - val_accuracy: 0.9856
# Epoch 89/100
# 390/390 [==============================] - 126s 322ms/step - loss: 0.0151 - accuracy: 0.9981 - val_loss: 0.0856 - val_accuracy: 0.9841
# Epoch 90/100
# 390/390 [==============================] - 126s 323ms/step - loss: 0.0155 - accuracy: 0.9978 - val_loss: 0.0863 - val_accuracy: 0.9848
# Epoch 91/100
# 390/390 [==============================] - 127s 325ms/step - loss: 0.0144 - accuracy: 0.9986 - val_loss: 0.0804 - val_accuracy: 0.9856
# Epoch 92/100
# 390/390 [==============================] - 126s 322ms/step - loss: 0.0146 - accuracy: 0.9986 - val_loss: 0.0858 - val_accuracy: 0.9856
# Epoch 93/100
# 390/390 [==============================] - 128s 326ms/step - loss: 0.0136 - accuracy: 0.9986 - val_loss: 0.0844 - val_accuracy: 0.9863
# Epoch 94/100
# 390/390 [==============================] - 127s 322ms/step - loss: 0.0152 - accuracy: 0.9979 - val_loss: 0.0858 - val_accuracy: 0.9848
# Epoch 95/100
# 390/390 [==============================] - 127s 324ms/step - loss: 0.0139 - accuracy: 0.9985 - val_loss: 0.0859 - val_accuracy: 0.9856
# Epoch 96/100
# 390/390 [==============================] - 126s 321ms/step - loss: 0.0130 - accuracy: 0.9986 - val_loss: 0.0805 - val_accuracy: 0.9856
# Epoch 97/100
# 390/390 [==============================] - 127s 324ms/step - loss: 0.0131 - accuracy: 0.9989 - val_loss: 0.0827 - val_accuracy: 0.9863
# Epoch 98/100
# 390/390 [==============================] - 127s 323ms/step - loss: 0.0133 - accuracy: 0.9986 - val_loss: 0.0807 - val_accuracy: 0.9863
# Epoch 99/100
# 390/390 [==============================] - 128s 324ms/step - loss: 0.0132 - accuracy: 0.9987 - val_loss: 0.0819 - val_accuracy: 0.9877
# Epoch 100/100
# 390/390 [==============================] - 127s 325ms/step - loss: 0.0125 - accuracy: 0.9989 - val_loss: 0.0833 - val_accuracy: 0.9863

# %% [markdown]
# # Model Evaluation

# %%
evaluate = workout_model.evaluate(val_ds)

epoch = range(len(history.history["loss"]))
plt.figure()
plt.plot(epoch, history.history['loss'], 'red', label = 'train_loss')
plt.plot(epoch, history.history['val_loss'], 'blue', label = 'val_loss')
plt.plot(epoch, history.history['accuracy'], 'orange', label = 'train_acc')
plt.plot(epoch, history.history['val_accuracy'], 'green', label = 'val_acc')
plt.title("Training Loss and Accuracy on Dataset")
plt.xlabel("Epoch #")
plt.ylabel("Loss/Accuracy")
plt.legend()
# Out:
# 44/44 [==============================] - 5s 96ms/step - loss: 0.0833 - accuracy: 0.9863

# %% [markdown]
# # Save Model History to csv

# %%
hist_df = pd.DataFrame(history.history)

hist_csv_file = 'VGG19_history.csv'
with open(hist_csv_file, mode='w') as f:
    hist_df.to_csv(f)

# %% [markdown]
# # Save The Model

# %%
current_datetime = datetime.now()

# Save Model
workout_model.save(f'workout_model_{current_datetime}')

# Save .h5 model
workout_model.save(f'workout_model_{current_datetime}.h5')

# Convert the model to tflite
converter = tf.lite.TFLiteConverter.from_saved_model(f'./workout_model_{current_datetime}')
tflite_model = converter.convert()

# Save the tflite model
with open(f'workout_model_{current_datetime}.tflite', 'wb') as f:
    f.write(tflite_model)
