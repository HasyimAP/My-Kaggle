# %%
import os
import cv2
import time
import random
import numpy as np 
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt

from collections import deque
from datetime import datetime
from tensorflow.keras.callbacks import EarlyStopping

# %% [markdown]
# # Set Hyperparameter

# %%
height = 256
width = 256
channels = 3
batch_size = 32
img_shape = (height, width, channels)
img_size = (height, width)

# %% [markdown]
# # Split The Dataset

# %%
DATA_DIR = '../input/workoutexercises-images'

train_ds = tf.keras.utils.image_dataset_from_directory(DATA_DIR,
                                                       labels = 'inferred',
                                                       label_mode = 'categorical',
                                                       validation_split = 0.1,
                                                       subset = 'training',
                                                       image_size = img_size,
                                                       shuffle = True,
                                                       batch_size = batch_size,
                                                       seed = 127
                                                      )

val_ds = tf.keras.utils.image_dataset_from_directory(DATA_DIR,
                                                     labels = 'inferred',
                                                     label_mode = 'categorical',
                                                     validation_split = 0.1,
                                                     subset = 'validation',
                                                     image_size = img_size,
                                                     shuffle = True,
                                                     batch_size = batch_size,
                                                     seed = 127
                                                    )

labels = train_ds.class_names
print(labels)

with open('workout_label.txt', 'w') as f:
    for workout_class in labels:
        f.write(f'{workout_class}\n')
# Out:
# Found 13853 files belonging to 22 classes.
# Using 12468 files for training.
# Found 13853 files belonging to 22 classes.
# Using 1385 files for validation.
# ['barbell biceps curl', 'bench press', 'chest fly machine', 'deadlift', 'decline bench press', 'hammer curl', 'hip thrust', 'incline bench press', 'lat pulldown', 'lateral raises', 'leg extension', 'leg raises', 'plank', 'pull up', 'push up', 'romanian deadlift', 'russian twist', 'shoulder press', 'squat', 't bar row', 'tricep dips', 'tricep pushdown']

# %% [markdown]
# # Data Augmentation

# %%
data_augmentation = tf.keras.Sequential([tf.keras.layers.RandomFlip("horizontal"),
                                         tf.keras.layers.GaussianNoise(10),
                                         tf.keras.layers.RandomContrast(0.1),
                                         tf.keras.layers.RandomZoom(0.2)
                                        ])

train_ds = train_ds.map(lambda x, y: (data_augmentation(x), y))

# %%
#Defing a function to see images
def show_img(data):
    plt.figure(figsize=(10,10))
    for images, labels in data.take(1):
        for i in range(9):
            ax = plt.subplot(3, 3, i + 1)
            ax.imshow(images[i].numpy().astype("uint8"))
            ax.axis("off")

#Plotting the images in dataset
show_img(train_ds)

# %% [markdown]
# # Load Pre-Trained Model

# %%
# load pre-trained model
pre_trained = tf.keras.applications.vgg19.VGG19(
    weights='imagenet', 
    include_top=False, 
    input_shape=img_shape, 
    pooling='avg'
)

for layer in pre_trained.layers:
    layer.trainable = False
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80134624/80134624 [==============================] - 3s 0us/step

# %%
x = pre_trained.output

predictions = tf.keras.layers.Dense(len(labels), activation='softmax')(x)

workout_model = tf.keras.models.Model(inputs = pre_trained.input, 
                                      outputs = predictions
                                     )

workout_model.compile(optimizer = tf.keras.optimizers.Adam(learning_rate=0.0001),
                      loss='categorical_crossentropy',
                      metrics=['accuracy']
                     )

workout_model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 256, 256, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 256, 256, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 256, 256, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 128, 128, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 128, 128, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 128, 128, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 64, 64, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 64, 64, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 64, 64, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 64, 64, 256)       590080
#
#  block3_conv4 (Conv2D)       (None, 64, 64, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 32, 32, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 32, 32, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 32, 32, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 32, 32, 512)       2359808
#
#  block4_conv4 (Conv2D)       (None, 32, 32, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 16, 16, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 16, 16, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 16, 16, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 16, 16, 512)       2359808
#
#  block5_conv4 (Conv2D)       (None, 16, 16, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 8, 8, 512)         0
#
#  global_average_pooling2d (G  (None, 512)              0
#  lobalAveragePooling2D)
#
#  dense (Dense)               (None, 22)                11286
#
# =================================================================
# Total params: 20,035,670
# Trainable params: 11,286
# Non-trainable params: 20,024,384
# _________________________________________________________________

# %% [markdown]
# # Train Model With Dataset

# %%
early_stopping_callback = EarlyStopping(monitor = 'val_loss', 
                                        patience = 5, 
                                        mode = 'auto', 
                                        restore_best_weights = True
                                       )

history = workout_model.fit(train_ds,
                            validation_data = val_ds,
                            epochs = 100
#                             callbacks = [early_stopping_callback]
                           )
# Out:
# Epoch 1/100
# 390/390 [==============================] - 167s 402ms/step - loss: 6.2772 - accuracy: 0.1120 - val_loss: 4.3551 - val_accuracy: 0.2181
# Epoch 2/100
# 390/390 [==============================] - 123s 313ms/step - loss: 3.2556 - accuracy: 0.2932 - val_loss: 2.5602 - val_accuracy: 0.4245
# Epoch 3/100
# 390/390 [==============================] - 122s 312ms/step - loss: 2.1385 - accuracy: 0.4607 - val_loss: 1.7226 - val_accuracy: 0.5668
# Epoch 4/100
# 390/390 [==============================] - 124s 316ms/step - loss: 1.5524 - accuracy: 0.5808 - val_loss: 1.2641 - val_accuracy: 0.6570
# Epoch 5/100
# 390/390 [==============================] - 123s 315ms/step - loss: 1.1926 - accuracy: 0.6683 - val_loss: 0.9904 - val_accuracy: 0.7264
# Epoch 6/100
# 390/390 [==============================] - 123s 314ms/step - loss: 0.9530 - accuracy: 0.7310 - val_loss: 0.8000 - val_accuracy: 0.7704
# Epoch 7/100
# 390/390 [==============================] - 127s 325ms/step - loss: 0.7869 - accuracy: 0.7800 - val_loss: 0.6602 - val_accuracy: 0.8159
# Epoch 8/100
# 390/390 [==============================] - 126s 320ms/step - loss: 0.6723 - accuracy: 0.8099 - val_loss: 0.5679 - val_accuracy: 0.8469
# Epoch 9/100
# 390/390 [==============================] - 124s 316ms/step - loss: 0.5683 - accuracy: 0.8433 - val_loss: 0.4931 - val_accuracy: 0.8729
# Epoch 10/100
# 390/390 [==============================] - 129s 330ms/step - loss: 0.4995 - accuracy: 0.8645 - val_loss: 0.4393 - val_accuracy: 0.8881
# Epoch 11/100
# 390/390 [==============================] - 125s 320ms/step - loss: 0.4420 - accuracy: 0.8829 - val_loss: 0.3854 - val_accuracy: 0.9025
# Epoch 12/100
# 390/390 [==============================] - 126s 321ms/step - loss: 0.3923 - accuracy: 0.8992 - val_loss: 0.3476 - val_accuracy: 0.9126
# Epoch 13/100
# 390/390 [==============================] - 123s 312ms/step - loss: 0.3579 - accuracy: 0.9083 - val_loss: 0.3160 - val_accuracy: 0.9148
# Epoch 14/100
# 390/390 [==============================] - 123s 314ms/step - loss: 0.3128 - accuracy: 0.9213 - val_loss: 0.2841 - val_accuracy: 0.9271
# Epoch 15/100
# 390/390 [==============================] - 123s 314ms/step - loss: 0.2889 - accuracy: 0.9262 - val_loss: 0.2624 - val_accuracy: 0.9336
# Epoch 16/100
# 390/390 [==============================] - 123s 313ms/step - loss: 0.2663 - accuracy: 0.9350 - val_loss: 0.2443 - val_accuracy: 0.9386
# Epoch 17/100
# 390/390 [==============================] - 123s 315ms/step - loss: 0.2491 - accuracy: 0.9370 - val_loss: 0.2244 - val_accuracy: 0.9430
# Epoch 18/100
# 390/390 [==============================] - 124s 318ms/step - loss: 0.2246 - accuracy: 0.9451 - val_loss: 0.2130 - val_accuracy: 0.9495
# Epoch 19/100
# 390/390 [==============================] - 123s 314ms/step - loss: 0.2101 - accuracy: 0.9479 - val_loss: 0.1959 - val_accuracy: 0.9531
# Epoch 20/100
# 390/390 [==============================] - 123s 313ms/step - loss: 0.1957 - accuracy: 0.9525 - val_loss: 0.1831 - val_accuracy: 0.9588
# Epoch 21/100
# 390/390 [==============================] - 123s 314ms/step - loss: 0.1802 - accuracy: 0.9585 - val_loss: 0.1746 - val_accuracy: 0.9588
# Epoch 22/100
# 390/390 [==============================] - 124s 315ms/step - loss: 0.1709 - accuracy: 0.9589 - val_loss: 0.1705 - val_accuracy: 0.9617
# Epoch 23/100
# 390/390 [==============================] - 124s 315ms/step - loss: 0.1581 - accuracy: 0.9621 - val_loss: 0.1621 - val_accuracy: 0.9639
# Epoch 24/100
# 390/390 [==============================] - 130s 331ms/step - loss: 0.1484 - accuracy: 0.9658 - val_loss: 0.1551 - val_accuracy: 0.9632
# Epoch 25/100
# 390/390 [==============================] - 125s 317ms/step - loss: 0.1442 - accuracy: 0.9669 - val_loss: 0.1504 - val_accuracy: 0.9653
# Epoch 26/100
# 390/390 [==============================] - 124s 316ms/step - loss: 0.1326 - accuracy: 0.9694 - val_loss: 0.1400 - val_accuracy: 0.9682
# Epoch 27/100
# 390/390 [==============================] - 123s 315ms/step - loss: 0.1259 - accuracy: 0.9737 - val_loss: 0.1385 - val_accuracy: 0.9639
# Epoch 28/100
# 390/390 [==============================] - 124s 315ms/step - loss: 0.1172 - accuracy: 0.9739 - val_loss: 0.1328 - val_accuracy: 0.9675
# Epoch 29/100
# 390/390 [==============================] - 124s 314ms/step - loss: 0.1098 - accuracy: 0.9764 - val_loss: 0.1303 - val_accuracy: 0.9675
# Epoch 30/100
# 390/390 [==============================] - 124s 317ms/step - loss: 0.1058 - accuracy: 0.9757 - val_loss: 0.1291 - val_accuracy: 0.9653
# Epoch 31/100
# 390/390 [==============================] - 124s 317ms/step - loss: 0.0993 - accuracy: 0.9774 - val_loss: 0.1279 - val_accuracy: 0.9704
# Epoch 32/100
# 390/390 [==============================] - 124s 317ms/step - loss: 0.0936 - accuracy: 0.9786 - val_loss: 0.1214 - val_accuracy: 0.9718
# Epoch 33/100
# 390/390 [==============================] - 124s 316ms/step - loss: 0.0882 - accuracy: 0.9803 - val_loss: 0.1199 - val_accuracy: 0.9697
# Epoch 34/100
# 390/390 [==============================] - 124s 317ms/step - loss: 0.0856 - accuracy: 0.9819 - val_loss: 0.1164 - val_accuracy: 0.9704
# Epoch 35/100
# 390/390 [==============================] - 127s 323ms/step - loss: 0.0822 - accuracy: 0.9824 - val_loss: 0.1152 - val_accuracy: 0.9704
# Epoch 36/100
# 390/390 [==============================] - 131s 334ms/step - loss: 0.0782 - accuracy: 0.9841 - val_loss: 0.1092 - val_accuracy: 0.9718
# Epoch 37/100
# 390/390 [==============================] - 132s 335ms/step - loss: 0.0775 - accuracy: 0.9839 - val_loss: 0.1077 - val_accuracy: 0.9740
# Epoch 38/100
# 390/390 [==============================] - 128s 327ms/step - loss: 0.0731 - accuracy: 0.9847 - val_loss: 0.1079 - val_accuracy: 0.9740
# Epoch 39/100
# 390/390 [==============================] - 126s 321ms/step - loss: 0.0681 - accuracy: 0.9856 - val_loss: 0.1026 - val_accuracy: 0.9747
# Epoch 40/100
# 390/390 [==============================] - 125s 319ms/step - loss: 0.0607 - accuracy: 0.9882 - val_loss: 0.1021 - val_accuracy: 0.9776
# Epoch 41/100
# 390/390 [==============================] - 125s 320ms/step - loss: 0.0617 - accuracy: 0.9885 - val_loss: 0.1006 - val_accuracy: 0.9762
# Epoch 42/100
# 390/390 [==============================] - 127s 322ms/step - loss: 0.0587 - accuracy: 0.9893 - val_loss: 0.0981 - val_accuracy: 0.9762
# Epoch 43/100
# 390/390 [==============================] - 126s 322ms/step - loss: 0.0555 - accuracy: 0.9893 - val_loss: 0.0974 - val_accuracy: 0.9762
# Epoch 44/100
# 390/390 [==============================] - 125s 320ms/step - loss: 0.0535 - accuracy: 0.9906 - val_loss: 0.0949 - val_accuracy: 0.9762
# Epoch 45/100
# 390/390 [==============================] - 127s 322ms/step - loss: 0.0516 - accuracy: 0.9903 - val_loss: 0.0971 - val_accuracy: 0.9783
# Epoch 46/100
# 390/390 [==============================] - 129s 327ms/step - loss: 0.0515 - accuracy: 0.9898 - val_loss: 0.0966 - val_accuracy: 0.9776
# Epoch 47/100
# 390/390 [==============================] - 126s 322ms/step - loss: 0.0487 - accuracy: 0.9909 - val_loss: 0.0936 - val_accuracy: 0.9776
# Epoch 48/100
# 390/390 [==============================] - 126s 322ms/step - loss: 0.0473 - accuracy: 0.9917 - val_loss: 0.0923 - val_accuracy: 0.9791
# Epoch 49/100
# 390/390 [==============================] - 126s 321ms/step - loss: 0.0453 - accuracy: 0.9928 - val_loss: 0.0932 - val_accuracy: 0.9791
# Epoch 50/100
# 390/390 [==============================] - 127s 323ms/step - loss: 0.0429 - accuracy: 0.9929 - val_loss: 0.0914 - val_accuracy: 0.9819
# Epoch 51/100
# 390/390 [==============================] - 127s 324ms/step - loss: 0.0406 - accuracy: 0.9933 - val_loss: 0.0894 - val_accuracy: 0.9798
# Epoch 52/100
# 390/390 [==============================] - 128s 327ms/step - loss: 0.0416 - accuracy: 0.9917 - val_loss: 0.0934 - val_accuracy: 0.9791
# Epoch 53/100
# 390/390 [==============================] - 126s 321ms/step - loss: 0.0394 - accuracy: 0.9932 - val_loss: 0.0886 - val_accuracy: 0.9783
# Epoch 54/100
# 390/390 [==============================] - 126s 322ms/step - loss: 0.0376 - accuracy: 0.9940 - val_loss: 0.0902 - val_accuracy: 0.9776
# Epoch 55/100
# 390/390 [==============================] - 126s 323ms/step - loss: 0.0375 - accuracy: 0.9930 - val_loss: 0.0878 - val_accuracy: 0.9798
# Epoch 56/100
# 390/390 [==============================] - 125s 319ms/step - loss: 0.0354 - accuracy: 0.9942 - val_loss: 0.0839 - val_accuracy: 0.9805
# Epoch 57/100
# 390/390 [==============================] - 129s 327ms/step - loss: 0.0339 - accuracy: 0.9948 - val_loss: 0.0892 - val_accuracy: 0.9798
# Epoch 58/100
# 390/390 [==============================] - 126s 321ms/step - loss: 0.0330 - accuracy: 0.9951 - val_loss: 0.0879 - val_accuracy: 0.9791
# Epoch 59/100
# 390/390 [==============================] - 127s 325ms/step - loss: 0.0325 - accuracy: 0.9948 - val_loss: 0.0856 - val_accuracy: 0.9805
# Epoch 60/100
# 390/390 [==============================] - 126s 322ms/step - loss: 0.0339 - accuracy: 0.9943 - val_loss: 0.0879 - val_accuracy: 0.9798
# Epoch 61/100
# 390/390 [==============================] - 126s 322ms/step - loss: 0.0297 - accuracy: 0.9961 - val_loss: 0.0869 - val_accuracy: 0.9798
# Epoch 62/100
# 390/390 [==============================] - 127s 325ms/step - loss: 0.0295 - accuracy: 0.9957 - val_loss: 0.0837 - val_accuracy: 0.9805
# Epoch 63/100
# 390/390 [==============================] - 130s 331ms/step - loss: 0.0282 - accuracy: 0.9966 - val_loss: 0.0843 - val_accuracy: 0.9819
# Epoch 64/100
# 390/390 [==============================] - 128s 327ms/step - loss: 0.0276 - accuracy: 0.9964 - val_loss: 0.0818 - val_accuracy: 0.9819
# Epoch 65/100
# 390/390 [==============================] - 127s 324ms/step - loss: 0.0268 - accuracy: 0.9964 - val_loss: 0.0882 - val_accuracy: 0.9812
# Epoch 66/100
# 390/390 [==============================] - 127s 325ms/step - loss: 0.0266 - accuracy: 0.9966 - val_loss: 0.0841 - val_accuracy: 0.9798
# Epoch 67/100
# 390/390 [==============================] - 129s 329ms/step - loss: 0.0261 - accuracy: 0.9963 - val_loss: 0.0842 - val_accuracy: 0.9798
# Epoch 68/100
# 390/390 [==============================] - 129s 330ms/step - loss: 0.0244 - accuracy: 0.9966 - val_loss: 0.0868 - val_accuracy: 0.9812
# Epoch 69/100
# 390/390 [==============================] - 131s 334ms/step - loss: 0.0239 - accuracy: 0.9970 - val_loss: 0.0814 - val_accuracy: 0.9812
# Epoch 70/100
# 390/390 [==============================] - 131s 335ms/step - loss: 0.0241 - accuracy: 0.9967 - val_loss: 0.0840 - val_accuracy: 0.9805
# Epoch 71/100
# 390/390 [==============================] - 130s 331ms/step - loss: 0.0237 - accuracy: 0.9972 - val_loss: 0.0832 - val_accuracy: 0.9812
# Epoch 72/100
# 390/390 [==============================] - 130s 331ms/step - loss: 0.0217 - accuracy: 0.9978 - val_loss: 0.0819 - val_accuracy: 0.9805
# Epoch 73/100
# 390/390 [==============================] - 131s 334ms/step - loss: 0.0232 - accuracy: 0.9966 - val_loss: 0.0800 - val_accuracy: 0.9812
# Epoch 74/100
# 390/390 [==============================] - 132s 336ms/step - loss: 0.0214 - accuracy: 0.9976 - val_loss: 0.0810 - val_accuracy: 0.9827
# Epoch 75/100
# 390/390 [==============================] - 132s 337ms/step - loss: 0.0204 - accuracy: 0.9975 - val_loss: 0.0771 - val_accuracy: 0.9827
# Epoch 76/100
# 390/390 [==============================] - 132s 337ms/step - loss: 0.0205 - accuracy: 0.9972 - val_loss: 0.0820 - val_accuracy: 0.9812
# Epoch 77/100
# 390/390 [==============================] - 132s 337ms/step - loss: 0.0188 - accuracy: 0.9980 - val_loss: 0.0794 - val_accuracy: 0.9819
# Epoch 78/100
# 390/390 [==============================] - 131s 335ms/step - loss: 0.0197 - accuracy: 0.9971 - val_loss: 0.0786 - val_accuracy: 0.9841
# Epoch 79/100
# 390/390 [==============================] - 132s 337ms/step - loss: 0.0182 - accuracy: 0.9980 - val_loss: 0.0794 - val_accuracy: 0.9827
# Epoch 80/100
# 390/390 [==============================] - 132s 337ms/step - loss: 0.0192 - accuracy: 0.9974 - val_loss: 0.0784 - val_accuracy: 0.9812
# Epoch 81/100
# 390/390 [==============================] - 132s 337ms/step - loss: 0.0179 - accuracy: 0.9980 - val_loss: 0.0790 - val_accuracy: 0.9819
# Epoch 82/100
# 390/390 [==============================] - 133s 340ms/step - loss: 0.0172 - accuracy: 0.9977 - val_loss: 0.0745 - val_accuracy: 0.9841
# Epoch 83/100
# 390/390 [==============================] - 131s 333ms/step - loss: 0.0174 - accuracy: 0.9977 - val_loss: 0.0795 - val_accuracy: 0.9827
# Epoch 84/100
# 390/390 [==============================] - 132s 336ms/step - loss: 0.0181 - accuracy: 0.9981 - val_loss: 0.0793 - val_accuracy: 0.9819
# Epoch 85/100
# 390/390 [==============================] - 133s 338ms/step - loss: 0.0163 - accuracy: 0.9978 - val_loss: 0.0762 - val_accuracy: 0.9827
# Epoch 86/100
# 390/390 [==============================] - 132s 336ms/step - loss: 0.0164 - accuracy: 0.9980 - val_loss: 0.0776 - val_accuracy: 0.9827
# Epoch 87/100
# 390/390 [==============================] - 133s 340ms/step - loss: 0.0159 - accuracy: 0.9981 - val_loss: 0.0812 - val_accuracy: 0.9805
# Epoch 88/100
# 390/390 [==============================] - 133s 339ms/step - loss: 0.0152 - accuracy: 0.9983 - val_loss: 0.0795 - val_accuracy: 0.9812
# Epoch 89/100
# 390/390 [==============================] - 138s 350ms/step - loss: 0.0142 - accuracy: 0.9986 - val_loss: 0.0826 - val_accuracy: 0.9827
# Epoch 90/100
# 390/390 [==============================] - 131s 334ms/step - loss: 0.0142 - accuracy: 0.9989 - val_loss: 0.0775 - val_accuracy: 0.9827
# Epoch 91/100
# 390/390 [==============================] - 133s 339ms/step - loss: 0.0155 - accuracy: 0.9982 - val_loss: 0.0757 - val_accuracy: 0.9827
# Epoch 92/100
# 390/390 [==============================] - 133s 340ms/step - loss: 0.0152 - accuracy: 0.9982 - val_loss: 0.0750 - val_accuracy: 0.9848
# Epoch 93/100
# 390/390 [==============================] - 132s 337ms/step - loss: 0.0151 - accuracy: 0.9973 - val_loss: 0.0781 - val_accuracy: 0.9841
# Epoch 94/100
# 390/390 [==============================] - 134s 341ms/step - loss: 0.0130 - accuracy: 0.9990 - val_loss: 0.0767 - val_accuracy: 0.9848
# Epoch 95/100
# 390/390 [==============================] - 132s 336ms/step - loss: 0.0130 - accuracy: 0.9986 - val_loss: 0.0756 - val_accuracy: 0.9841
# Epoch 96/100
# 390/390 [==============================] - 132s 338ms/step - loss: 0.0124 - accuracy: 0.9990 - val_loss: 0.0754 - val_accuracy: 0.9841
# Epoch 97/100
# 390/390 [==============================] - 133s 340ms/step - loss: 0.0128 - accuracy: 0.9984 - val_loss: 0.0770 - val_accuracy: 0.9834
# Epoch 98/100
# 390/390 [==============================] - 132s 337ms/step - loss: 0.0118 - accuracy: 0.9990 - val_loss: 0.0731 - val_accuracy: 0.9841
# Epoch 99/100
# 390/390 [==============================] - 131s 336ms/step - loss: 0.0130 - accuracy: 0.9985 - val_loss: 0.0747 - val_accuracy: 0.9834
# Epoch 100/100
# 390/390 [==============================] - 133s 339ms/step - loss: 0.0120 - accuracy: 0.9991 - val_loss: 0.0738 - val_accuracy: 0.9848

# %% [markdown]
# # Model Evaluation

# %%
evaluate = workout_model.evaluate(val_ds)

epoch = range(len(history.history["loss"]))
plt.figure()
plt.plot(epoch, history.history['loss'], 'red', label = 'train_loss')
plt.plot(epoch, history.history['val_loss'], 'blue', label = 'val_loss')
plt.plot(epoch, history.history['accuracy'], 'orange', label = 'train_acc')
plt.plot(epoch, history.history['val_accuracy'], 'green', label = 'val_acc')
plt.title("Training Loss and Accuracy on Dataset")
plt.xlabel("Epoch #")
plt.ylabel("Loss/Accuracy")
plt.legend()
# Out:
# 44/44 [==============================] - 5s 95ms/step - loss: 0.0738 - accuracy: 0.9848

# %% [markdown]
# # Save Model History to csv

# %%
hist_df = pd.DataFrame(history.history)

hist_csv_file = 'VGG19_history.csv'
with open(hist_csv_file, mode='w') as f:
    hist_df.to_csv(f)

# %% [markdown]
# # Save The Model

# %%
current_datetime = datetime.now()

# Save Model
workout_model.save(f'workout_model_{current_datetime}')

# Save .h5 model
workout_model.save(f'workout_model_{current_datetime}.h5')

# Convert the model to tflite
converter = tf.lite.TFLiteConverter.from_saved_model(f'./workout_model_{current_datetime}')
tflite_model = converter.convert()

# Save the tflite model
with open(f'workout_model_{current_datetime}.tflite', 'wb') as f:
    f.write(tflite_model)

# %% [markdown]
# # Testing Model

# %%
interpreter = tf.lite.Interpreter(model_path = f'/kaggle/working/workout_model_{current_datetime}.tflite')
interpreter.allocate_tensors()

input_details = interpreter.get_input_details()
output_details = interpreter.get_output_details()

print("== Input details ==")
print("name:", input_details[0]['name'])
print("shape:", input_details[0]['shape'])
print("type:", input_details[0]['dtype'])

print("\n== Output details ==")
print("name:", output_details[0]['name'])
print("shape:", output_details[0]['shape'])
print("type:", output_details[0]['dtype'])
# Out:
# == Input details ==
# name: serving_default_input_1:0
# shape: [  1 256 256   3]
# type: <class 'numpy.float32'>
#
# == Output details ==
# name: StatefulPartitionedCall:0
# shape: [ 1 22]
# type: <class 'numpy.float32'>
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.

# %%
random_classes_names = random.choice(os.listdir('/kaggle/input/workoutfitness-video'))
random_file = random.choice(os.listdir(f'/kaggle/input/workoutfitness-video/{random_classes_names}'))
print(f'{random_classes_names}/{random_file}\n')

# Construct the input video file path
input_video_file_path = f'/kaggle/input/workoutfitness-video/{random_classes_names}/{random_file}'

# import label from txt file
labels = []
with open('/kaggle/working/workout_label.txt', 'r') as f:
    for row in f:
        labels.append(row)
        

# Initialize video input
video_capture = cv2.VideoCapture(input_video_file_path)
writer = None
H, W = None, None
Q = deque(maxlen=128)
n = 0
img_size = (256, 256)

fps = video_capture.get(cv2.CAP_PROP_FPS)
frame_count = video_capture.get(cv2.CAP_PROP_FRAME_COUNT)
duration = frame_count/fps

print(f'Duration: {duration}')
print(f'FPS: {fps}')
print(f'Total frame: {frame_count}\n')

print('Prediction process')
start_time = time.time()

scan_count = 0
# Loop through each frame in the video
while True:
    # read a frame
    success, frame = video_capture.read()
    
    # if frame not read properly then break the loop
    if not success:
        break
    
    # count the frame
    n += 1
    
    if duration < 5.0:
        # predict every 10 frame (1, 11, 21, ... etc)
        step = 10
    elif duration < 10.0:
        # predict every 15 frame (1, 16, 31, ... etc)
        step = 15
    else:
        # predict every 30 frame (1, 31, 61, ... etc)
        step = 30
    
    if n % step != 1:
        continue
    
    # get frame dimensions
    if W is None or H is None:
        (H, W) = frame.shape[:2]
    
    # clone the frame for the output then preprocess the frame for the prediction
    output = frame.copy()
    frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
    frame = cv2.resize(frame, img_size).astype("float32")
    
    interpreter.set_tensor(input_details[0]['index'], np.expand_dims(frame, axis=0))

    interpreter.invoke()

    predictions = interpreter.get_tensor(output_details[0]['index'])[0]
    
    Q.append(predictions)
    
    results = np.array(Q).mean(axis=0)
    i = np.argmax(results)
    label = labels[i]
    
    text = f'{label}'
#     cv2.putText(output, text, (35, 50), cv2.FONT_HERSHEY_SIMPLEX, 3, (0, 255, 0), 10)
    
#     if writer is None:
#         fourcc = cv2.VideoWriter_fourcc(*"XVID")
#         writer = cv2.VideoWriter('output.avi', fourcc, 30, (W, H), True)
        
#     writer.write(output)
    
#     plt.imshow(output)
#     plt.axis('off')
    
    print(f'{n}, {text}\t{results[i]}')
    scan_count += 1
    
    target_frame = int(fps*2)
    
    # break the loop if prediction > 90% and video already more than 2 seconds (fps*2)
    if results[i] >= 0.9 and n >= target_frame:
        break

end_time = time.time()

print(f'\nActual video: {random_file}')
print(f'Prediction: {text}')
print(f'confidence: {results[i]}')
print(f'Prediction time: {end_time - start_time} sec')
print(f'Scan speed: {(end_time - start_time)/scan_count} per frame\n')

# writer.release()
# video_capture.release()

result_df = pd.DataFrame({'exercise': labels,
                          'percentage': results
                         })

result_df['exercise'] = result_df['exercise'].str.strip()
result_df = result_df.sort_values('percentage', ascending=False)
result_df = result_df.reset_index(drop=True)

result_df
# Out:
# push-up/push-up_41.mp4
#
# Duration: 3.6036
# FPS: 29.97002997002997
# Total frame: 108.0
#
# Prediction process
# 1, push up
# 	0.9999923706054688
# 11, push up
# 	0.9999837875366211
# 21, push up
# 	0.9999887347221375
# 31, push up
# 	0.9999883770942688
# 41, push up
# 	0.999988853931427
# 51, push up
# 	0.9999859929084778
# 61, push up
# 	0.9999880194664001
#
# Actual video: push-up_41.mp4
# Prediction: push up
#
# confidence: 0.9999880194664001
# Prediction time: 4.971746921539307 sec
# Scan speed: 0.7102495602199009 per frame
#                exercise    percentage
# 0               push up  9.999880e-01
# 1               pull up  4.659723e-06
# 2                 plank  3.568122e-06
# 3            hip thrust  1.665955e-06
# 4           bench press  7.004416e-07
# 5           tricep dips  4.804994e-07
# 6     chest fly machine  2.634616e-07
# 7        lateral raises  2.563979e-07
# 8                 squat  2.015838e-07
# 9         leg extension  1.165845e-07
# 10    romanian deadlift  3.182326e-08
# 11      tricep pushdown  1.584340e-08
# 12         lat pulldown  9.259977e-09
# 13             deadlift  6.733952e-09
# 14  decline bench press  2.507627e-09
# 15            t bar row  2.472786e-09
# 16       shoulder press  1.371579e-09
# 17           leg raises  1.865075e-10
# 18  barbell biceps curl  1.555120e-10
# 19          hammer curl  3.745115e-11
# 20  incline bench press  2.677458e-11
# 21        russian twist  4.168314e-13
